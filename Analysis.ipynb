# %% [markdown]
# # analysis

# %%
import pandas as pd

# %%
df = pd.read_csv("ncr_ride_bookings.csv")

# %%
df.describe()
# Out:
#             Avg VTAT       Avg CTAT  Cancelled Rides by Customer  \
# count  139500.000000  102000.000000                      10500.0
# mean        8.456352      29.149636                          1.0
# std         3.773564       8.902577                          0.0
# min         2.000000      10.000000                          1.0
# 25%         5.300000      21.600000                          1.0
# 50%         8.300000      28.800000                          1.0
# 75%        11.300000      36.800000                          1.0
# max        20.000000      45.000000                          1.0
#
#        Cancelled Rides by Driver  Incomplete Rides  Booking Value  \
# count                    27000.0            9000.0  102000.000000
# mean                         1.0               1.0     508.295912
# std                          0.0               0.0     395.805774
# min                          1.0               1.0      50.000000
# ...

# %%
df[["Booking Value","Avg CTAT"]]
# Out:
#         Booking Value  Avg CTAT
# 0                 NaN       NaN
# 1               237.0      14.0
# 2               627.0      25.8
# 3               416.0      28.5
# 4               737.0      19.6
# ...               ...       ...
# 149995          475.0      44.4
# 149996         1093.0      30.8
# 149997          852.0      23.4
# 149998          333.0      39.6
# 149999          806.0      33.7
#
# [150000 rows x 2 columns]

# %%
df[["Booking Value","Ride Distance"]].iloc[:100].plot(kind="scatter",x="Ride Distance", y="Booking Value")
# Out:
# <Axes: xlabel='Ride Distance', ylabel='Booking Value'>

# %%
df.groupby("Payment Method").plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.groupby("Payment Method")["Date"].plot(kind="bar")
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:744, in GroupByPlot.__call__(self, *args, **kwargs)
#     741     return self.plot(*args, **kwargs)
#     743 f.__name__ = "plot"
# --> 744 return self._groupby._python_apply_general(f, self._groupby._selected_obj)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1886, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1851 @final
#    1852 def _python_apply_general(
#    1853     self,
#    (...)   1858     is_agg: bool = False,
#    1859 ) -> NDFrameT:
#    1860     """
#    1861     Apply function f in python space
#    1862
#    (...)   1884         data after applying f
#    1885     """
# ...
